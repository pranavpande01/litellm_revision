# %%
import litellm, os 
from litellm import completion

messages = [{"role": "user", "content": "Hey, how's it going"}]
a=completion(model="gemini/gemini-2.5-flash", messages=messages)
print(litellm._current_cost)
# Out:
# 0.0

# %%
a.choices[0].message.content
# Out:
# "Hey there! I'm doing well, thanks for asking. How about you? How's your day going so far?"
